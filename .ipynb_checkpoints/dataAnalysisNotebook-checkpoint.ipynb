# %% [markdown]
# # Data Analysis
# ## Looking for Datasets
# I searched for the first dataset on data.gov, where I looked for interesting health data. The most interesting one was NCHC's [dataset](https://catalog.data.gov/dataset/age-adjusted-death-rates-for-the-top-10-leading-causes-of-death-united-states-2013) on leading causes of death. This dataset contains data on number deaths that the 10 deadliest diseases caused in each state from 1999 to 2015. It also contains the age-adjusted death rate, which is great for running analyses, since it accounts for the age of people living in each state and it is per 100,000 people.
#
# I had to find other dataset and combine the two to find something interesting. I thought it might be cool to find whether any disease is more prevalent in areas with lower level of education. After a bit of looking for data with Education Attainment, I found a good dataset on the Cencus Bureau's [American FactFinder](https://factfinder.census.gov/faces/nav/jsf/pages/searchresults.xhtml?refresh=t). I used the 2010 data since that one should be the most accurate. This dataset contains the maximum level of education completed by population that is 25 years or older. It also contains information about race and many other things that I did not need to use in this analysis.
#
# I used this notebook to keep track of my thoughts while trying to find something in the data.
#
# ## Coding

# %%
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt

mortality = pd.read_csv('NCHS_-_Leading_Causes_of_Death__United_States.csv')
education = pd.read_csv('ACS_10_5YR_S1501_with_ann.csv', skiprows=1) #first row is unnecessary

# %% [markdown]
# Get only data for 2010 disease since that is the year that I have data about education.

# %%
disease = mortality[mortality['Cause Name'] == 'Stroke']
disease = disease[disease['Year'] == 2010]
disease = disease.set_index('State')
disease = disease.drop(['Year','113 Cause Name'],axis=1)

# %% [markdown]
# Ommited some data that was unnecessary. Only got data about total population and percentages of highest level of education.

# %%
indexList = [2,3] + list(range(9,51,6))
educationLvl = education.iloc[:,indexList]
educationLvl = educationLvl.set_index('Geography')

# %% [markdown]
# Combined the two datasets.

# %%
educationDisease = educationLvl.merge(disease, left_index=True, right_index=True)

# %% [markdown]
# Decided to run correlation on a couple of diseases. Tried Stroke, Alzheimer's, Heart Diseases, then went back to stroke, by changing the value above.

# %%
print(stats.pearsonr(educationDisease["Total; Estimate; Bachelor's degree"],educationDisease['Age-adjusted Death Rate']))
# Out:
# (-0.6382313661757949, 4.696342090034126e-07)

# %% [markdown]
# Turns out that **Stroke** has the best correlation to education level. It is **negatively correlated**, which means that the lower the education, the higher the chance of dying on stroke.
#
# ### Graphing
#
# There is bug in matplotlib 2.1.2 that sorts the data automatically even if I have it sorted by the value. I found a workaround on [StackOverflow](https://stackoverflow.com/questions/47373762/pyplot-sorting-y-values-automatically).

# %%
educationDisease.sort_values('Age-adjusted Death Rate', inplace=True)

# %% [markdown]
# Now I want to find a nice way to represent this statistic. My goal is to combine the death rates with education levels in one chart.

# %%
color1 = 'tab:red'
fig, ax1 = plt.subplots(figsize=(19,10)) #bigger chart area
plt.xticks(range(len(educationDisease.index)), educationDisease.index,rotation=90)
ax1.set_xlabel('State')
ax1.set_ylabel('Death rate by Stroke', color=color1)
ax1.bar(range(len(educationDisease.index)), educationDisease['Age-adjusted Death Rate'], color=color1)
ax1.tick_params(axis='y', labelcolor=color1)

ax2 = ax1.twinx()

color = 'tab:cyan'
ax2.set_ylabel("Percentage of people with Bachelor's degree", color=color)
ax2.plot(range(len(educationDisease.index)), educationDisease["Total; Estimate; Bachelor's degree"], marker='o', linestyle='None', color=color)
ax2.tick_params(axis='y', labelcolor=color)

# %% [markdown]
# This graph shows that the more the people who have Bachelor's degree in a particular state, the less death because of stroke happened in the state.
#
# I want to save the graph into a file.

# %%
fig.tight_layout()
fig.savefig('graph.png')
plt.show()
